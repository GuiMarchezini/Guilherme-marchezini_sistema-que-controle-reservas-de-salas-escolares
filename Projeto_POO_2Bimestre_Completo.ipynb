# %% [markdown]
# # 📘 Projeto de Programação Orientada a Objetos – 2º Bimestre
#
# **Nome do Aluno:**
#
# **Turma:**
#
# **Tema Escolhido:**

# %% [markdown]
# Lembre-se esse projeto deve ser personalizado, todas as classe e metodos devem ter uma referencia ao seu nome, exemplo:
#
# class Carro_Fabio:
#
#     def __init__(self, tipo, cor, rodas):
#         self.tipo = tipo
#         self.cor = cor
#         self.rodas = rodas
#
#     def alterar_cor_Fabio(self, nova_cor):
#         self.cor = nova_cor
#         return self.cor

# %% [markdown]
# ## PARTE 1 – Classe Principal e Objetos
#
# **Tarefas:**
# - Definir e criar a classe principal com pelo menos 3 atributos.
# - Implementar o método construtor (`__init__`).
# - Criar pelo menos 2 objetos da classe principal.
# - Implementar um método de exibição de dados.
#
# **Código:**

# %%
class ReservaSala_GuilhermeMarchezini:
    def __init__(self, sala_GuilhermeMarchezini, responsavel_GuilhermeMarchezini, horario_GuilhermeMarchezini):
        self.sala_GuilhermeMarchezini = sala_GuilhermeMarchezini
        self.responsavel_GuilhermeMarchezini = responsavel_GuilhermeMarchezini
        self.horario_GuilhermeMarchezini = horario_GuilhermeMarchezini

    def exibir_reserva_GuilhermeMarchezini(self):
        print("=== Dados da Reserva - Guilherme Marchezini ===")
        print(f"Sala: {self.sala_GuilhermeMarchezini}")
        print(f"Responsável: {self.responsavel_GuilhermeMarchezini}")
        print(f"Horário: {self.horario_GuilhermeMarchezini}")
        print("==============================================\n")


reserva1_GuilhermeMarchezini = ReservaSala_GuilhermeMarchezini("Sala 101", "Prof. Ana Souza", "14:00 - 15:00")
reserva2_GuilhermeMarchezini = ReservaSala_GuilhermeMarchezini("Sala 202", "Prof. João Lima", "09:00 - 10:30")


reserva1_GuilhermeMarchezini.exibir_reserva_GuilhermeMarchezini()
reserva2_GuilhermeMarchezini.exibir_reserva_GuilhermeMarchezini()



reserva1.exibir_reserva()
reserva2.exibir_reserva()
class ReservaSala:
    def __init__(self, sala, responsavel, horario):
        self.sala = sala
        self.responsavel = responsavel
        self.horario = horario

    def exibir_reserva(self):
        print("=== Dados da Reserva ===")
        print(f"Sala: {self.sala}")
        print(f"Responsável: {self.responsavel}")
        print(f"Horário: {self.horario}")
        print("========================\n")
# Out:
# === Dados da Reserva - Guilherme Marchezini ===
# Sala: Sala 101
# Responsável: Prof. Ana Souza
# Horário: 14:00 - 15:00
# ...
#
# === Dados da Reserva - Guilherme Marchezini ===
# Sala: Sala 202
# Responsável: Prof. João Lima
# Horário: 09:00 - 10:30
# ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 24
#      19 reserva1_GuilhermeMarchezini.exibir_reserva_GuilhermeMarchezini()
#      20 reserva2_GuilhermeMarchezini.exibir_reserva_GuilhermeMarchezini()
# ---> 24 reserva1.exibir_reserva()
#      25 reserva2.exibir_reserva()
#      26 class ReservaSala:
#
# NameError: name 'reserva1' is not defined

# %% [markdown]
# ## PARTE 2 – Métodos e Herança
#
# **Tarefas:**
# - Criar pelo menos 2 métodos de ação para a classe principal.
# - Criar uma subclasse herdando da classe principal.
# - Adicionar pelo menos 1 novo atributo e 1 novo método exclusivo na subclasse.
# - Utilizar `super()` no construtor da subclasse.
#
# **Código:**

# %%
class ReservaSala_GuilhermeMarchezini:
    def __init__(self, sala_GuilhermeMarchezini, responsavel_GuilhermeMarchezini, horario_GuilhermeMarchezini):
        self.sala_GuilhermeMarchezini = sala_GuilhermeMarchezini
        self.responsavel_GuilhermeMarchezini = responsavel_GuilhermeMarchezini
        self.horario_GuilhermeMarchezini = horario_GuilhermeMarchezini

    def exibir_reserva_GuilhermeMarchezini(self):
        print("=== Dados da Reserva - Guilherme Marchezini ===")
        print(f"Sala: {self.sala_GuilhermeMarchezini}")
        print(f"Responsável: {self.responsavel_GuilhermeMarchezini}")
        print(f"Horário: {self.horario_GuilhermeMarchezini}")
        print("==============================================\n")

    def alterar_horario_GuilhermeMarchezini(self, novo_horario_GuilhermeMarchezini):
        self.horario_GuilhermeMarchezini = novo_horario_GuilhermeMarchezini
        print(f"Horário alterado para: {self.horario_GuilhermeMarchezini}")

    def cancelar_reserva_GuilhermeMarchezini(self):
        print(f"Reserva da sala {self.sala_GuilhermeMarchezini} foi cancelada.")
        self.sala_GuilhermeMarchezini = None
        self.responsavel_GuilhermeMarchezini = None
        self.horario_GuilhermeMarchezini = None


class ReservaLaboratorio_GuilhermeMarchezini(ReservaSala_GuilhermeMarchezini):
    def __init__(self, sala_GuilhermeMarchezini, responsavel_GuilhermeMarchezini, horario_GuilhermeMarchezini, equipamentos_GuilhermeMarchezini):
        super().__init__(sala_GuilhermeMarchezini, responsavel_GuilhermeMarchezini, horario_GuilhermeMarchezini)
        self.equipamentos_GuilhermeMarchezini = equipamentos_GuilhermeMarchezini

    def verificar_equipamentos_GuilhermeMarchezini(self):
        print(f"Equipamentos disponíveis na sala {self.sala_GuilhermeMarchezini}:")
        for item in self.equipamentos_GuilhermeMarchezini:
            print(f" - {item}")
        print()

        print()
class ReservaLaboratorio(ReservaSala):
    def __init__(self, sala, responsavel, horario, equipamentos):
        super().__init__(sala, responsavel, horario)  # Construtor da superclasse
        self.equipamentos = equipamentos  # ✅ Novo atributo exclusivo

    def verificar_equipamentos(self):  # ✅ Novo método exclusivo da subclasse
        print(f"Equipamentos disponíveis no laboratório {self.sala}:")
        for item in self.equipamentos:
            print(f" - {item}")
        print()

class ReservaSala_GuilhermeMarchezini:
    def __init__(self, sala_GuilhermeMarchezini, responsavel_GuilhermeMarchezini, horario_GuilhermeMarchezini):
        self.sala_GuilhermeMarchezini = sala_GuilhermeMarchezini
        self.responsavel_GuilhermeMarchezini = responsavel_GuilhermeMarchezini
        self.horario_GuilhermeMarchezini = horario_GuilhermeMarchezini

    def exibir_reserva_GuilhermeMarchezini(self):
        print("=== Dados da Reserva - Guilherme Marchezini ===")
        print(f"Sala: {self.sala_GuilhermeMarchezini}")
        print(f"Responsável: {self.responsavel_GuilhermeMarchezini}")
        print(f"Horário: {self.horario_GuilhermeMarchezini}")
        print("==============================================\n")


class ReservaLaboratorio_GuilhermeMarchezini(ReservaSala_GuilhermeMarchezini):
    def __init__(self, sala_GuilhermeMarchezini, responsavel_GuilhermeMarchezini, horario_GuilhermeMarchezini, equipamentos_GuilhermeMarchezini):
        super().__init__(sala_GuilhermeMarchezini, responsavel_GuilhermeMarchezini, horario_GuilhermeMarchezini)
        self.equipamentos_GuilhermeMarchezini = equipamentos_GuilhermeMarchezini

    def verificar_equipamentos_GuilhermeMarchezini(self):
        print(f"Equipamentos disponíveis no laboratório {self.sala_GuilhermeMarchezini}:")
        for item in self.equipamentos_GuilhermeMarchezini:
            print(f" - {item}")
        print()

# %% [markdown]
# ## PARTE 3 – Encapsulamento e Abstração
#
# **Tarefas:**
# - Tornar pelo menos 1 atributo da classe principal privado (`__atributo`).
# - Criar métodos `get` e `set` para o atributo privado.
# - Implementar um método que contenha lógica interna (ex: cálculo, verificação).
#
# **Código:**

# %%
class ReservaSala_GuilhermeMarchezini:
    def __init__(self, sala, responsavel, horario):
        self.__sala = sala  # Atributo privado
        self.responsavel = responsavel
        self.horario = horario

   
    def get_sala(self):
        return self.__sala

    
    def set_sala(self, nova_sala):
        if isinstance(nova_sala, str) and nova_sala.strip() != "":
            self.__sala = nova_sala
        else:
            print("Erro: Nome da sala inválido.")

    
    def verificar_disponibilidade(self, horario_desejado):
        if self.horario == horario_desejado:
            return "Horário indisponível."
        else:
            return "Horário disponível."

    
    def exibir_reserva(self):
        print("=== Dados da Reserva ===")
        print(f"Sala: {self.__sala}")
        print(f"Responsável: {self.responsavel}")
        print(f"Horário: {self.horario}")
        print("========================\n")

# %% [markdown]
# ## PARTE 4 – Polimorfismo e Banco de Dados
#
# **Tarefas:**
# - Implementar polimorfismo: sobrescrever um método na subclasse.
# - Integrar o sistema com banco de dados (MySQL ou SQLite).
# - Implementar inserção (INSERT), consulta (SELECT) e exclusão (DELETE) de registros no banco de dados.
#
# **Código:**

# %%
import sqlite3


class ReservaSala_GuilhermeMarchezini:
    def __init__(self, sala, responsavel, horario):
        self.sala = sala
        self.responsavel = responsavel
        self.horario = horario

    def exibir_reserva(self):
        print("=== Reserva de Sala ===")
        print(f"Sala: {self.sala}")
        print(f"Responsável: {self.responsavel}")
        print(f"Horário: {self.horario}")
        print("=======================\n")


class ReservaLaboratorio_GuilhermeMarchezini(ReservaSala_GuilhermeMarchezini):
    def __init__(self, sala, responsavel, horario, equipamentos):
        super().__init__(sala, responsavel, horario)
        self.equipamentos = equipamentos

    
    def exibir_reserva(self):
        print("=== Reserva de Laboratório ===")
        print(f"Sala: {self.sala}")
        print(f"Responsável: {self.responsavel}")
        print(f"Horário: {self.horario}")
        print("Equipamentos:")
        for item in self.equipamentos:
            print(f" - {item}")
        print("==============================\n")


conn = sqlite3.connect('reservas.db')
cursor = conn.cursor()


cursor.execute('''
    CREATE TABLE IF NOT EXISTS reservas (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        sala TEXT,
        responsavel TEXT,
        horario TEXT
    )
''')
conn.commit()


def inserir_reserva(sala, responsavel, horario):
    cursor.execute("INSERT INTO reservas (sala, responsavel, horario) VALUES (?, ?, ?)", (sala, responsavel, horario))
    conn.commit()
    print("Reserva inserida com sucesso!\n")


def listar_reservas():
    cursor.execute("SELECT * FROM reservas")
    resultados = cursor.fetchall()
    if resultados:
        for reserva in resultados:
            print(f"ID: {reserva[0]} | Sala: {reserva[1]} | Responsável: {reserva[2]} | Horário: {reserva[3]}")
    else:
        print("Nenhuma reserva encontrada.")
    print()


def excluir_reserva(id_reserva):
    cursor.execute("DELETE FROM reservas WHERE id = ?", (id_reserva,))
    conn.commit()
    print(f"Reserva com ID {id_reserva} excluída.\n")




reserva1 = ReservaSala_GuilhermeMarchezini("Sala 101", "Prof. Ana", "14:00 - 15:00")
reserva2 = ReservaLaboratorio_GuilhermeMarchezini("Lab 305", "Prof. João", "10:00 - 12:00", ["Projetor", "Computadores"])


reserva1.exibir_reserva()
reserva2.exibir_reserva()


inserir_reserva(reserva1.sala, reserva1.responsavel, reserva1.horario)
inserir_reserva(reserva2.sala, reserva2.responsavel, reserva2.horario)


listar_reservas()


excluir_reserva(1)


listar_reservas()


conn.close()

# %% [markdown]
# ## PARTE 5 – Projeto Final e Organização
#
# **Tarefas:**
# - Consolidar todas as partes do projeto em um único script organizado.
# - Comentar o código explicando cada parte.
# - Testar todas as funcionalidades.
#
# **Código:**

# %%
import sqlite3


class ReservaSala_GuilhermeMarchezini:
    def __init__(self, sala, responsavel, horario):
        self.__sala = sala  
        self.responsavel = responsavel
        self.horario = horario

    
    def get_sala(self):
        return self.__sala

  
    def set_sala(self, nova_sala):
        if isinstance(nova_sala, str) and nova_sala.strip() != "":
            self.__sala = nova_sala
        else:
            print("Erro: nome de sala inválido.")

    
    def verificar_disponibilidade(self, horario_desejado):
        return "Indisponível" if self.horario == horario_desejado else "Disponível"

    # Método que pode ser sobrescrito
    def exibir_reserva(self):
        print("=== Reserva de Sala ===")
        print(f"Sala: {self.__sala}")
        print(f"Responsável: {self.responsavel}")
        print(f"Horário: {self.horario}")
        print("=======================\n")


class ReservaLaboratorio_GuilhermeMarchezini(ReservaSala_GuilhermeMarchezini):
    def __init__(self, sala, responsavel, horario, equipamentos):
        super().__init__(sala, responsavel, horario)
        self.equipamentos = equipamentos

    
    def exibir_reserva(self):
        print("=== Reserva de Laboratório ===")
        print(f"Sala: {self.get_sala()}")
        print(f"Responsável: {self.responsavel}")
        print(f"Horário: {self.horario}")
        print("Equipamentos:")
        for equipamento in self.equipamentos:
            print(f" - {equipamento}")
        print("==============================\n")



conn = sqlite3.connect('reservas.db')
cursor = conn.cursor()
cursor.execute('''
    CREATE TABLE IF NOT EXISTS reservas (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        sala TEXT,
        responsavel TEXT,
        horario TEXT
    )
''')
conn.commit()


def inserir_reserva(sala, responsavel, horario):
    cursor.execute("INSERT INTO reservas (sala, responsavel, horario) VALUES (?, ?, ?)",
                   (sala, responsavel, horario))
    conn.commit()
    print("✅ Reserva inserida com sucesso!\n")


def listar_reservas():
    print("📋 Listagem de Reservas:")
    cursor.execute("SELECT * FROM reservas")
    reservas = cursor.fetchall()
    if reservas:
        for r in reservas:
            print(f"ID: {r[0]} | Sala: {r[1]} | Responsável: {r[2]} | Horário: {r[3]}")
    else:
        print("Nenhuma reserva encontrada.")
    print()


def excluir_reserva(id_reserva):
    cursor.execute("DELETE FROM reservas WHERE id = ?", (id_reserva,))
    conn.commit()
    print(f"❌ Reserva com ID {id_reserva} foi excluída.\n")


reserva1 = ReservaSala_GuilhermeMarchezini("Sala 101", "Prof. Ana Souza", "14:00 - 15:00")
reserva2 = ReservaLaboratorio_GuilhermeMarchezini("Lab 305", "Prof. João Lima", "10:00 - 12:00",
                                                  ["Projetor", "Computadores", "Quadro Digital"])


reserva1.exibir_reserva()
reserva2.exibir_reserva()


inserir_reserva(reserva1.get_sala(), reserva1.responsavel, reserva1.horario)
inserir_reserva(reserva2.get_sala(), reserva2.responsavel, reserva2.horario)


listar_reservas()


excluir_reserva(1)


listar_reservas()


print("Sala atual da reserva1:", reserva1.get_sala())
reserva1.set_sala("Sala 202")
print("Sala alterada:", reserva1.get_sala())
print("Disponibilidade 14:00 - 15:00:", reserva1.verificar_disponibilidade("14:00 - 15:00"))
print("Disponibilidade 15:00 - 16:00:", reserva1.verificar_disponibilidade("15:00 - 16:00"))


conn.close()
